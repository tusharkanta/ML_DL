# %% [markdown]
# <a href="https://colab.research.google.com/github/tusharkanta/ML_DL/blob/eva/S8/S8_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
from google.colab import files
#src = list(files.upload().values())[0]
#open('dataloader.py','wb').write(src)
#import dataloader
import dataloader as dl
#src = list(files.upload().values())[0]
#open('plotimagefinal.py','wb').write(src)
#import dataloader
import plotimagefinal as pimage
src = list(files.upload().values())[0]
open('modeldefresnetfinal.py','wb').write(src)
import modeldefresnetfinal as modeldef
import torch
#src = list(files.upload().values())[0]
#open('modeltraintestdef.py','wb').write(src)
import modeltraintestdef as modeltrt
#src = list(files.upload().values())[0]
#open('miscellaneous3.py','wb').write(src)
import miscellaneous3 as misc
# Out:
#      <input type="file" id="files-0189f343-7d76-4ae9-848d-f444e1aaab03" name="files[]" multiple disabled />
#      <output id="result-0189f343-7d76-4ae9-848d-f444e1aaab03">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving modeldefresnetfinal.py to modeldefresnetfinal.py

# %%
train_loader,test_loader,classes=dl.load_data()
pimage.show_random_images(train_loader,classes)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# CUDA Available? True
# plane   dog  deer  deer

# %%
# !pip install torchsummary
from torchsummary import summary
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print(device)
model = modeldef.ResNet18().to(device)
summary(model, input_size=(3, 32, 32))
# Out:
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.6/dist-packages (1.5.1)
# cuda
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#        BasicBlock-12           [-1, 64, 32, 32]               0
#            Conv2d-13          [-1, 128, 16, 16]          73,728
#       BatchNorm2d-14          [-1, 128, 16, 16]             256
#            Conv2d-15          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-16          [-1, 128, 16, 16]             256
#            Conv2d-17          [-1, 128, 16, 16]           8,192
#       BatchNorm2d-18          [-1, 128, 16, 16]             256
#        BasicBlock-19          [-1, 128, 16, 16]               0
#            Conv2d-20          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-21          [-1, 128, 16, 16]             256
#            Conv2d-22          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-23          [-1, 128, 16, 16]             256
#        BasicBlock-24          [-1, 128, 16, 16]               0
#            Conv2d-25            [-1, 256, 8, 8]         294,912
#       BatchNorm2d-26            [-1, 256, 8, 8]             512
#            Conv2d-27            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-28            [-1, 256, 8, 8]             512
#            Conv2d-29            [-1, 256, 8, 8]          32,768
#       BatchNorm2d-30            [-1, 256, 8, 8]             512
#        BasicBlock-31            [-1, 256, 8, 8]               0
#            Conv2d-32            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-33            [-1, 256, 8, 8]             512
#            Conv2d-34            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-35            [-1, 256, 8, 8]             512
#        BasicBlock-36            [-1, 256, 8, 8]               0
#            Conv2d-37            [-1, 512, 4, 4]       1,179,648
#       BatchNorm2d-38            [-1, 512, 4, 4]           1,024
#            Conv2d-39            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-40            [-1, 512, 4, 4]           1,024
#            Conv2d-41            [-1, 512, 4, 4]         131,072
#       BatchNorm2d-42            [-1, 512, 4, 4]           1,024
#        BasicBlock-43            [-1, 512, 4, 4]               0
#            Conv2d-44            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-45            [-1, 512, 4, 4]           1,024
#            Conv2d-46            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-47            [-1, 512, 4, 4]           1,024
#        BasicBlock-48            [-1, 512, 4, 4]               0
#            Linear-49                   [-1, 10]           5,130
# ================================================================
# Total params: 11,173,962
# Trainable params: 11,173,962
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 11.25
# Params size (MB): 42.63
# Estimated Total Size (MB): 53.89
# ----------------------------------------------------------------

# %%
import torch.optim as optim
#model =  modeldef.Net().to(device)
optimizer = optim.SGD(model.parameters(), lr=0.008, momentum=0.9)
EPOCHS = 35
for epoch in range(EPOCHS):
    print("EPOCH:", epoch)
    modeltrt.train(model, device, train_loader, optimizer, epoch)
    modeltrt.test(model, device, test_loader)
# Out:
#   0%|          | 0/2084 [00:00<?, ?it/s]
# EPOCH: 0
# Loss=1.0772287845611572 Accuracy=50.60: 100%|██████████| 2084/2084 [03:32<00:00,  9.17it/s]
#   0%|          | 0/2084 [00:00<?, ?it/s]
# Test set: Avg loss: 1.0406, Accuracy: 6425/10000 (64.25%)
#
# EPOCH: 1
# Loss=1.243118166923523 Accuracy=72.06: 100%|██████████| 2084/2084 [03:33<00:00,  8.51it/s]
#   0%|          | 0/2084 [00:00<?, ?it/s]
# Test set: Avg loss: 0.7702, Accuracy: 7404/10000 (74.04%)
#
# EPOCH: 2
# Loss=0.7998694181442261 Accuracy=79.65: 100%|██████████| 2084/2084 [03:31<00:00,  8.31it/s]
#   0%|          | 0/2084 [00:00<?, ?it/s]
# Test set: Avg loss: 0.5899, Accuracy: 7954/10000 (79.54%)
#
# EPOCH: 3
# Loss=0.3558422923088074 Accuracy=84.45: 100%|██████████| 2084/2084 [03:33<00:00,  8.44it/s]
#   0%|          | 0/2084 [00:00<?, ?it/s]
# Test set: Avg loss: 0.5424, Accuracy: 8147/10000 (81.47%)
#
# EPOCH: 4
# Loss=1.1641852855682373 Accuracy=87.96: 100%|██████████| 2084/2084 [03:32<00:00,  9.07it/s]
#   0%|          | 0/2084 [00:00<?, ?it/s]
# Test set: Avg loss: 0.5391, Accuracy: 8266/10000 (82.66%)
#
# EPOCH: 5
# Loss=0.49027663469314575 Accuracy=90.92: 100%|██████████| 2084/2084 [03:34<00:00,  8.51it/s]
#   0%|          | 0/2084 [00:00<?, ?it/s]
# Test set: Avg loss: 0.6000, Accuracy: 8120/10000 (81.20%)
#
# EPOCH: 6
# Loss=0.021462976932525635 Accuracy=93.33: 100%|██████████| 2084/2084 [03:32<00:00,  8.50it/s]
#   0%|          | 0/2084 [00:00<?, ?it/s]
# Test set: Avg loss: 0.6175, Accuracy: 8160/10000 (81.60%)
#
# EPOCH: 7
# Loss=1.33837890625 Accuracy=94.90: 100%|██████████| 2084/2084 [03:33<00:00,  9.09it/s]
#   0%|          | 0/2084 [00:00<?, ?it/s]
# Test set: Avg loss: 0.6539, Accuracy: 8278/10000 (82.78%)
#
# EPOCH: 8
# Loss=0.004486739635467529 Accuracy=96.27: 100%|██████████| 2084/2084 [03:32<00:00,  8.53it/s]
#   0%|          | 0/2084 [00:00<?, ?it/s]
# Test set: Avg loss: 0.6557, Accuracy: 8309/10000 (83.09%)
#
# EPOCH: 9
# Loss=0.009597301483154297 Accuracy=97.25: 100%|██████████| 2084/2084 [03:33<00:00,  8.63it/s]
#   0%|          | 0/2084 [00:00<?, ?it/s]
# Test set: Avg loss: 0.6457, Accuracy: 8408/10000 (84.08%)
#
# EPOCH: 10
# Loss=0.0024999380111694336 Accuracy=98.17: 100%|██████████| 2084/2084 [03:32<00:00,  8.46it/s]
#   0%|          | 0/2084 [00:00<?, ?it/s]
# Test set: Avg loss: 0.7289, Accuracy: 8376/10000 (83.76%)
#
# EPOCH: 11
# Loss=0.19696781039237976 Accuracy=98.57: 100%|██████████| 2084/2084 [03:34<00:00,  8.56it/s]
#   0%|          | 0/2084 [00:00<?, ?it/s]
# Test set: Avg loss: 0.7595, Accuracy: 8301/10000 (83.01%)
#
# EPOCH: 12
# Loss=0.0023723840713500977 Accuracy=98.75: 100%|██████████| 2084/2084 [03:32<00:00,  8.37it/s]
#   0%|          | 0/2084 [00:00<?, ?it/s]
# Test set: Avg loss: 0.7908, Accuracy: 8257/10000 (82.57%)
#
# EPOCH: 13
# Loss=0.8714026808738708 Accuracy=98.72: 100%|██████████| 2084/2084 [03:34<00:00,  8.52it/s]
#   0%|          | 0/2084 [00:00<?, ?it/s]
# Test set: Avg loss: 0.8178, Accuracy: 8247/10000 (82.47%)
#
# EPOCH: 14
# Loss=0.03885972499847412 Accuracy=99.01: 100%|██████████| 2084/2084 [03:31<00:00,  9.35it/s]
#   0%|          | 0/2084 [00:00<?, ?it/s]
# Test set: Avg loss: 0.7377, Accuracy: 8449/10000 (84.49%)
#
# EPOCH: 15
# Loss=0.1785377860069275 Accuracy=99.32: 100%|██████████| 2084/2084 [03:33<00:00,  8.40it/s]
#   0%|          | 0/2084 [00:00<?, ?it/s]
# Test set: Avg loss: 0.8202, Accuracy: 8362/10000 (83.62%)
#
# EPOCH: 16
# Loss=0.010649561882019043 Accuracy=99.17: 100%|██████████| 2084/2084 [03:33<00:00,  8.55it/s]
#   0%|          | 0/2084 [00:00<?, ?it/s]
# Test set: Avg loss: 0.7921, Accuracy: 8425/10000 (84.25%)
#
# EPOCH: 17
# Loss=0.0003107786178588867 Accuracy=99.43: 100%|██████████| 2084/2084 [03:34<00:00,  9.73it/s]
#   0%|          | 0/2084 [00:00<?, ?it/s]
# Test set: Avg loss: 0.7739, Accuracy: 8370/10000 (83.70%)
#
# EPOCH: 18
# Loss=0.0002880096435546875 Accuracy=99.48: 100%|██████████| 2084/2084 [03:32<00:00,  8.48it/s]
#   0%|          | 0/2084 [00:00<?, ?it/s]
# Test set: Avg loss: 0.8055, Accuracy: 8408/10000 (84.08%)
#
# EPOCH: 19
# Loss=0.001990795135498047 Accuracy=99.64: 100%|██████████| 2084/2084 [03:35<00:00,  9.26it/s]
#   0%|          | 0/2084 [00:00<?, ?it/s]
# Test set: Avg loss: 0.7976, Accuracy: 8503/10000 (85.03%)
#
# EPOCH: 20
# Loss=0.000500798225402832 Accuracy=99.69: 100%|██████████| 2084/2084 [03:33<00:00,  9.22it/s]
#   0%|          | 0/2084 [00:00<?, ?it/s]
# Test set: Avg loss: 0.8107, Accuracy: 8425/10000 (84.25%)
#
# EPOCH: 21
# Loss=0.026146531105041504 Accuracy=99.80: 100%|██████████| 2084/2084 [03:33<00:00,  8.42it/s]
#   0%|          | 0/2084 [00:00<?, ?it/s]
# Test set: Avg loss: 0.8603, Accuracy: 8398/10000 (83.98%)
#
# EPOCH: 22
# Loss=0.0002372264862060547 Accuracy=99.77: 100%|██████████| 2084/2084 [03:32<00:00,  9.13it/s]
#   0%|          | 0/2084 [00:00<?, ?it/s]
# Test set: Avg loss: 0.7936, Accuracy: 8470/10000 (84.70%)
#
# EPOCH: 23
# Loss=0.002272486686706543 Accuracy=99.81: 100%|██████████| 2084/2084 [03:33<00:00,  8.46it/s]
#   0%|          | 0/2084 [00:00<?, ?it/s]
# Test set: Avg loss: 0.8246, Accuracy: 8530/10000 (85.30%)
#
# EPOCH: 24
# Loss=0.2011352777481079 Accuracy=99.76: 100%|██████████| 2084/2084 [03:33<00:00,  9.26it/s]
#   0%|          | 0/2084 [00:00<?, ?it/s]
# Test set: Avg loss: 0.8807, Accuracy: 8457/10000 (84.57%)
#
# EPOCH: 25
# Loss=0.0001405477523803711 Accuracy=99.78: 100%|██████████| 2084/2084 [03:33<00:00,  8.31it/s]
#   0%|          | 0/2084 [00:00<?, ?it/s]
# Test set: Avg loss: 0.8024, Accuracy: 8545/10000 (85.45%)
#
# EPOCH: 26
# Loss=3.147125244140625e-05 Accuracy=99.91: 100%|██████████| 2084/2084 [03:32<00:00,  9.82it/s]
#   0%|          | 0/2084 [00:00<?, ?it/s]
# Test set: Avg loss: 0.8148, Accuracy: 8523/10000 (85.23%)
#
# EPOCH: 27
# Loss=0.0012142658233642578 Accuracy=99.95: 100%|██████████| 2084/2084 [03:34<00:00,  8.54it/s]
#   0%|          | 0/2084 [00:00<?, ?it/s]
# Test set: Avg loss: 0.8170, Accuracy: 8506/10000 (85.06%)
#
# EPOCH: 28
# Loss=0.022652864456176758 Accuracy=99.96: 100%|██████████| 2084/2084 [03:33<00:00,  9.10it/s]
#   0%|          | 0/2084 [00:00<?, ?it/s]
# Test set: Avg loss: 0.8229, Accuracy: 8556/10000 (85.56%)
#
# EPOCH: 29
# Loss=0.0006742477416992188 Accuracy=99.95: 100%|██████████| 2084/2084 [03:33<00:00,  8.53it/s]
#   0%|          | 0/2084 [00:00<?, ?it/s]
# Test set: Avg loss: 0.8671, Accuracy: 8503/10000 (85.03%)
#
# EPOCH: 30
# Loss=2.384185791015625e-07 Accuracy=99.95: 100%|██████████| 2084/2084 [03:33<00:00,  8.50it/s]
#   0%|          | 0/2084 [00:00<?, ?it/s]
# Test set: Avg loss: 0.8379, Accuracy: 8563/10000 (85.63%)
#
# EPOCH: 31
# Loss=0.002905130386352539 Accuracy=99.89: 100%|██████████| 2084/2084 [03:34<00:00,  9.12it/s]
#   0%|          | 0/2084 [00:00<?, ?it/s]
# Test set: Avg loss: 0.8982, Accuracy: 8534/10000 (85.34%)
#
# EPOCH: 32
# Loss=0.0004342794418334961 Accuracy=99.91: 100%|██████████| 2084/2084 [03:33<00:00,  8.52it/s]
#   0%|          | 0/2084 [00:00<?, ?it/s]
# Test set: Avg loss: 0.8807, Accuracy: 8541/10000 (85.41%)
#
# EPOCH: 33
# Loss=0.00010895729064941406 Accuracy=99.92: 100%|██████████| 2084/2084 [03:33<00:00,  8.40it/s]
#   0%|          | 0/2084 [00:00<?, ?it/s]
# Test set: Avg loss: 0.8798, Accuracy: 8524/10000 (85.24%)
#
# EPOCH: 34
# Loss=3.7670135498046875e-05 Accuracy=99.96: 100%|██████████| 2084/2084 [03:32<00:00,  8.50it/s]
# Test set: Avg loss: 0.8922, Accuracy: 8532/10000 (85.32%)

# %%
#Okay, first step. Let us display an image from the test set to get familiar. Consider only 4 images from a batch
images=misc.prtgroundtruth(test_loader,classes)
# Out:
# GroundTruth:   bird   dog  frog truck

# %%
#Get the index of the highest energy (accuracy of those 4 images)
misc.getTestAccuracy(model,images,classes,test_loader,device)
# Out:
# Predicted:   bird   dog  frog truck
# Accuracy of the network on the 10000 test images: 85 %

# %%
# 
# what are the classes that performed well, and the classes that did not perform well:
misc.getclassaccuracy(model,test_loader,classes,device)
# Out:
# Accuracy of plane : 86 %
# Accuracy of   car : 95 %
# Accuracy of  bird : 80 %
# Accuracy of   cat : 77 %
# Accuracy of  deer : 82 %
# Accuracy of   dog : 76 %
# Accuracy of  frog : 90 %
# Accuracy of horse : 92 %
# Accuracy of  ship : 90 %
# Accuracy of truck : 87 %
