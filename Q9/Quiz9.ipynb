# %% [markdown]
# <a href="https://colab.research.google.com/github/tusharkanta/ML_DL/blob/eva/Q9/Quiz9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import datetime
# %matplotlib inline
from google.colab import files
src = list(files.upload().values())[0]
open('dataloaderquiz.py','wb').write(src)
import dataloaderquiz as dl
src = list(files.upload().values())[0]
open('plotimagefinal.py','wb').write(src)
import plotimagefinal as pimage
src = list(files.upload().values())[0]
open('quizdnn3.py','wb').write(src)
import quizdnn3 as modeldef
import torch
# Out:
#      <input type="file" id="files-abdb2edf-a652-4a19-bb35-18dbf2f38aa4" name="files[]" multiple disabled />
#      <output id="result-abdb2edf-a652-4a19-bb35-18dbf2f38aa4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dataloaderquiz.py to dataloaderquiz.py
#      <input type="file" id="files-d65a852c-baae-4a92-ab7b-7dca63aa1d48" name="files[]" multiple disabled />
#      <output id="result-d65a852c-baae-4a92-ab7b-7dca63aa1d48">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving plotimagefinal.py to plotimagefinal.py
# ...

# %%
datetime_object = datetime.datetime.now()
print("Current Date/Time: ",datetime_object)
# Out:
# Current Date/Time:  2020-03-17 05:36:15.284302

# %%
train_loader,test_loader,classes=dl.load_data()
pimage.show_random_images(train_loader,classes)
# Out:
# ...
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
#
# Total dataset(train+test) shape:  (60000, 32, 32, 3)
# mean0 0.49186864
# mean1 0.48265335
# mean2 0.44717798
# std0 0.24697131
# std1 0.24338901
# std2 0.26159254
# channel mean 0.47390000025431317
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
#
# Total dataset(train+test) shape:  (60000, 32, 32, 3)
# meandata[0]: 0.49186864
# Files already downloaded and verified
# CUDA Available? True
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# plane   dog  deer  deer

# %%
# !pip install torchsummary
from torchsummary import summary
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print(device)
model = modeldef.Net().to(device)
summary(model, input_size=(3, 32, 32))
# Out:
# ...
# cuda
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 30, 30]           1,728
#               ReLU-2           [-1, 64, 30, 30]               0
#        BatchNorm2d-3           [-1, 64, 30, 30]             128
#            Dropout-4           [-1, 64, 30, 30]               0
#             Conv2d-5          [-1, 128, 28, 28]          73,728
#               ReLU-6          [-1, 128, 28, 28]               0
#        BatchNorm2d-7          [-1, 128, 28, 28]             256
#            Dropout-8          [-1, 128, 28, 28]               0
#             Conv2d-9          [-1, 256, 26, 26]         294,912
#              ReLU-10          [-1, 256, 26, 26]               0
#       BatchNorm2d-11          [-1, 256, 26, 26]             512
#           Dropout-12          [-1, 256, 26, 26]               0
#         MaxPool2d-13          [-1, 256, 13, 13]               0
# ...

# %%
import torch.optim as optim
#model =  modeldef.net().to(device)
optimizer = optim.SGD(model.parameters(), lr=0.008, momentum=0.9)
EPOCHS = 15
for epoch in range(EPOCHS):
    print("EPOCH:", epoch)
    modeldef.train(model, device, train_loader, optimizer, epoch)
    modeldef.test(model, device, test_loader)
# Out:
#   0%|          | 0/782 [00:00<?, ?it/s]
# EPOCH: 0
# ...
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Avg loss: 1.1499, Accuracy: 5974/10000 (59.74%)
#
# EPOCH: 1
# ...
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Avg loss: 0.8914, Accuracy: 6901/10000 (69.01%)
#
# EPOCH: 2
# ...
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Avg loss: 0.8763, Accuracy: 6964/10000 (69.64%)
#
# EPOCH: 3
# ...
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Avg loss: 0.7280, Accuracy: 7461/10000 (74.61%)
#
# EPOCH: 4
# ...
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Avg loss: 0.6828, Accuracy: 7700/10000 (77.00%)
#
# EPOCH: 5
# ...
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Avg loss: 0.6461, Accuracy: 7824/10000 (78.24%)
#
# EPOCH: 6
# ...
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Avg loss: 0.6127, Accuracy: 7941/10000 (79.41%)
#
# EPOCH: 7
# ...
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Avg loss: 0.5774, Accuracy: 8002/10000 (80.02%)
#
# EPOCH: 8
# ...
